# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-120,120,110)
y = [i*i -2*i +1 for i in x]
plt.xlim(-110,110)
plt.ylim(-10,10000)
plt.plot(x,y)
plt.show()

# %%
y = x**2 -2*x +1
plt.plot(x,y)
plt.show()
